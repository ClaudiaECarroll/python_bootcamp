# %% [markdown]
# # **Data Cleaning**
#
# Introducing:
#
# *   Duplicates
# *   Dates and Times
# *   Reorganizing Data
# *   Null Values

# %% [markdown]
# ## **Data Cleaning Basics**

# %%
import pandas as pd

# %%
df_SAFI = pd.read_csv("/content/drive/MyDrive/python_bootcamp/sample_data/SAFI.csv")

# %%
df_SAFI.head()
# Out:
#    Column1 interview_date  quest_no                     start  \
# 0        0     17/11/2016         1  2017-03-23T09:49:57.000Z
# 1        1     17/11/2016         1  2017-04-02T09:48:16.000Z
# 2        2     17/11/2016         3  2017-04-02T14:35:26.000Z
# 3        3     17/11/2016         4  2017-04-02T14:55:18.000Z
# 4        4     17/11/2016         5  2017-04-02T15:10:35.000Z
#
#                         end   province   district   ward   village  \
# 0  2017-04-02T17:29:08.000Z  Province1  District1  Ward2  Village2
# 1  2017-04-02T17:26:19.000Z  Province1  District1  Ward2  Village2
# 2  2017-04-02T17:26:53.000Z  Province1  District1  Ward2  Village2
# 3  2017-04-02T17:27:16.000Z  Province1  District1  Ward2  Village2
# 4  2017-04-02T17:27:35.000Z  Province1  District1  Ward2  Village2
#
#    years_farm  ... du_look_aftr_cows liv_count  no_meals members_count note  \
# 0          11  ...                no         1         2             3  NaN
# 1           2  ...                no         3         2             7  NaN
# 2          40  ...                no         1         2            10  NaN
# 3           6  ...                no         2         2             7  NaN
# 4          18  ...                no         4         2             7  NaN
#
#   gps:Accuracy gps:Altitude  gps:Latitude gps:Longitude  \
# 0         14.0          698    -19.112259     33.483456
# 1         19.0          690    -19.112477     33.483416
# 2         13.0          674    -19.112108     33.483450
# 3          5.0          679    -19.112229     33.483424
# 4         10.0          689    -19.112217     33.483425
#
#                                   instanceID
# 0  uuid:ec241f2c-0609-46ed-b5e8-fe575f6cefef
# 1  uuid:099de9c9-3e5e-427b-8452-26250e840d6e
# 2  uuid:193d7daf-9582-409b-bf09-027dd36f9007
# 3  uuid:148d1105-778a-4755-aa71-281eadd4a973
# 4  uuid:2c867811-9696-4966-9866-f35c3e97d02d
#
# [5 rows x 55 columns]

# %%
#Checking column headers

df_SAFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Column1                     133 non-null    int64
#  1   interview_date              133 non-null    object
#  2   quest_no                    133 non-null    int64
#  3   start                       133 non-null    object
#  4   end                         133 non-null    object
#  5   province                    133 non-null    object
#  6   district                    133 non-null    object
#  7   ward                        133 non-null    object
#  8   village                     133 non-null    object
#  9   years_farm                  133 non-null    int64
#  10  agr_assoc                   133 non-null    object
#  11  remittance_money            133 non-null    object
#  12  years_liv                   133 non-null    int64
#  13  parents_liv                 133 non-null    object
#  14  sp_parents_liv              133 non-null    object
#  15  grand_liv                   133 non-null    object
#  16  sp_grand_liv                133 non-null    object
#  17  no_membrs                   133 non-null    int64
#  18  respondent_roof_type        133 non-null    object
#  19  respondent_wall_type        133 non-null    object
#  20  respondent_wall_type_other  0 non-null      float64
#  21  respondent_floor_type       133 non-null    object
#  22  window_type                 133 non-null    object
#  23  buildings_in_compound       133 non-null    int64
#  24  rooms                       133 non-null    int64
#  25  other_buildings             133 non-null    object
#  26  plots_count                 133 non-null    int64
#  27  water_use                   133 non-null    object
#  28  no_enough_water             94 non-null     object
#  29  period_use                  94 non-null     float64
#  30  exper_other                 94 non-null     object
#  31  other_meth                  94 non-null     object
#  32  memb_assoc                  94 non-null     object
#  33  resp_assoc                  34 non-null     object
#  34  fees_water                  94 non-null     object
#  35  affect_conflicts            94 non-null     object
#  36  no_group_count              39 non-null     float64
#  37  yes_group_count             94 non-null     float64
#  38  need_money                  94 non-null     object
#  39  money_source_other          0 non-null      float64
#  40  crops_contr                 94 non-null     object
#  41  emply_lab                   133 non-null    object
#  42  du_labour                   133 non-null    object
#  43  liv_owned_other             0 non-null      float64
#  44  poultry                     133 non-null    object
#  45  du_look_aftr_cows           133 non-null    object
#  46  liv_count                   133 non-null    int64
#  47  no_meals                    133 non-null    int64
#  48  members_count               133 non-null    int64
#  49  note                        0 non-null      float64
#  50  gps:Accuracy                133 non-null    float64
#  51  gps:Altitude                133 non-null    int64
#  52  gps:Latitude                133 non-null    float64
#  53  gps:Longitude               133 non-null    float64
#  54  instanceID                  133 non-null    object
# dtypes: float64(10), int64(12), object(33)
# memory usage: 57.3+ KB

# %% [markdown]
# ## Check for Duplicate Rows

# %%
# Check for duplicates

duplicates = df_SAFI[df_SAFI.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [Column1, interview_date, quest_no, start, end, province, district, ward, village, years_farm, agr_assoc, remittance_money, years_liv, parents_liv, sp_parents_liv, grand_liv, sp_grand_liv, no_membrs, respondent_roof_type, respondent_wall_type, respondent_wall_type_other, respondent_floor_type, window_type, buildings_in_compound, rooms, other_buildings, plots_count, water_use, no_enough_water, period_use, exper_other, other_meth, memb_assoc, resp_assoc, fees_water, affect_conflicts, no_group_count, yes_group_count, need_money, money_source_other, crops_contr, emply_lab, du_labour, liv_owned_other, poultry, du_look_aftr_cows, liv_count, no_meals, members_count, note, gps:Accuracy, gps:Altitude, gps:Latitude, gps:Longitude, instanceID]
# Index: []
#
# [0 rows x 55 columns]

# %%
# Remove duplicate rows
df_SAFI = df_SAFI.drop_duplicates()

# %% [markdown]
# ## Dealing with Dates and Times in Pandas

# %%
df_SAFI["interview_date"]
# Out:
# 0      17/11/2016
# 1      17/11/2016
# 2      17/11/2016
# 3      17/11/2016
# 4      17/11/2016
#           ...
# 126    18/05/2017
# 127    04/06/2017
# 128    04/06/2017
# 129    04/06/2017
# 130    04/06/2017
# Name: interview_date, Length: 131, dtype: object

# %%
df_SAFI["interview_date"][0]
# Out:
# '17/11/2016'

# %%
type(df_SAFI["interview_date"][0])
# Out:
# str

# %%
# Converting certain columns to a pandas datetime object for stability and analysis

df_SAFI['interview_date'] = pd.to_datetime(df_SAFI['interview_date'], dayfirst=True)

# %%
type(df_SAFI["interview_date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Converting the datetime objects BACK to string format, in a format specified.
# To see different formatting options: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

df_SAFI['interview_date'] = df_SAFI['interview_date'].dt.strftime('%Y-%m-%d')

# %%
df_SAFI["interview_date"][0]
# Out:
# '2016-11-17'

# %%
type(df_SAFI["interview_date"][0])
# Out:
# str

# %% [markdown]
# ## Alphabetizing by Columns

# %%
df_SAFI = df_SAFI.sort_values(by='respondent_roof_type')
df_SAFI["respondent_roof_type"]
# Out:
# 0              grass
# 11             grass
# 5              grass
# 4              grass
# 13             grass
#            ...
# 7      mabatisloping
# 10     mabatisloping
# 12     mabatisloping
# 21     mabatisloping
# 132    mabatisloping
# Name: respondent_roof_type, Length: 132, dtype: object

# %%
df_SAFI = df_SAFI.sort_values(by='respondent_roof_type', ascending=False)
df_SAFI["respondent_roof_type"]
# Out:
# 132    mabatisloping
# 103    mabatisloping
# 53     mabatisloping
# 24     mabatisloping
# 94     mabatisloping
#            ...
# 72             grass
# 118            grass
# 69             grass
# 8              grass
# 105            grass
# Name: respondent_roof_type, Length: 132, dtype: object

# %% [markdown]
# ## Standardizing Case

# %%
df_SAFI['village']
# Out:
# 132    Village3
# 103    Village1
# 53     Village3
# 24     Village1
# 94     Village1
#          ...
# 72     Village3
# 118    Village2
# 69     Village3
# 8      Village3
# 105    Village2
# Name: village, Length: 132, dtype: object

# %%
 df_SAFI["village"] = df_SAFI['village'].str.lower()

# %%
df_SAFI['village']
# Out:
# 132    village3
# 103    village1
# 53     village3
# 24     village1
# 94     village1
#          ...
# 72     village3
# 118    village2
# 69     village3
# 8      village3
# 105    village2
# Name: village, Length: 132, dtype: object

# %% [markdown]
# ## Renaming Columns

# %%
new_columns = {col: col.strip().lower().replace('_', '-') for col in df_SAFI.columns}
df_SAFI.rename(columns=new_columns, inplace=True)

# %%
df_SAFI.columns
# Out:
# Index(['column1', 'interview-date', 'quest-no', 'start', 'end', 'province',
#        'district', 'ward', 'village', 'years-farm', 'agr-assoc',
#        'remittance-money', 'years-liv', 'parents-liv', 'sp-parents-liv',
#        'grand-liv', 'sp-grand-liv', 'no-membrs', 'respondent-roof-type',
#        'respondent-wall-type', 'respondent-wall-type-other',
#        'respondent-floor-type', 'window-type', 'buildings-in-compound',
#        'rooms', 'other-buildings', 'plots-count', 'water-use',
#        'no-enough-water', 'period-use', 'exper-other', 'other-meth',
#        'memb-assoc', 'resp-assoc', 'fees-water', 'affect-conflicts',
#        'no-group-count', 'yes-group-count', 'need-money', 'money-source-other',
#        'crops-contr', 'emply-lab', 'du-labour', 'liv-owned-other', 'poultry',
#        'du-look-aftr-cows', 'liv-count', 'no-meals', 'members-count', 'note',
#        'gps:accuracy', 'gps:altitude', 'gps:latitude', 'gps:longitude',
#        'instanceid'],
#       dtype='object')

# %%
df_SAFI.rename(columns={'gps:accuracy': 'gps-accuracy', 'gps:altitude': 'gps-altitude'}, inplace=True)

# %% [markdown]
# ## Exercise: Data Cleaning Basics
#
# Using the gdp_europe.csv file from earlier, clean the data in the following ways:
#
# 1.   Make the country names lowercase
# 2.   Put the rows in descending order of the GDP in Europe in 2007
# 3. Convery the column headers to datetime format

# %%
df_europe = pd.read_csv("/content/drive/MyDrive/python_bootcamp/sample_data/gdp_europe.csv")

# %%
df_europe.head()
# Out:
#                   country         1952         1957          1962  \
# 0                 Albania  1601.056136  1942.284244   2312.888958
# 1                 Austria  6137.076492  8842.598030  10750.721110
# 2                 Belgium  8343.105127  9714.960623  10991.206760
# 3  Bosnia and Herzegovina   973.533195  1353.989176   1709.683679
# 4                Bulgaria  2444.286648  3008.670727   4254.337839
#
#            1967          1972          1977          1982          1987  \
# 0   2760.196931   3313.422188   3533.003910   3630.880722   3738.932735
# 1  12834.602400  16661.625600  19749.422300  21597.083620  23687.826070
# 2  13149.041190  16672.143560  19117.974480  20979.845890  22525.563080
# 3   2172.352423   2860.169750   3528.481305   4126.613157   4314.114757
# 4   5577.002800   6597.494398   7612.240438   8224.191647   8239.854824
#
#            1992          1997          2002          2007
# 0   2497.437901   3193.054604   4604.211737   5937.029526
# 1  27042.018680  29095.920660  32417.607690  36126.492700
# 2  25575.570690  27561.196630  30485.883750  33692.605080
# 3   2546.781445   4766.355904   6018.975239   7446.298803
# 4   6302.623438   5970.388760   7696.777725  10680.792820

# %%
df_europe['country'] = df_europe['country'].str.lower()
df_europe = df_europe.sort_values(by='2007', ascending=False)

# %%
new_columns = []

for col in df_europe.columns:
    if col != 'country':
        new_columns.append(pd.to_datetime(col, format='%Y'))
    else:
        new_columns.append(col)

df_europe.columns = new_columns

# %%
df_europe.head()
# Out:
#         country  1952-01-01 00:00:00  1957-01-01 00:00:00  \
# 18       norway         10095.421720         11653.973040
# 14      ireland          5210.280328          5599.077872
# 27  switzerland         14734.232750         17909.489730
# 17  netherlands          8941.571858         11276.193440
# 13      iceland          7267.688428          9244.001412
#
#     1962-01-01 00:00:00  1967-01-01 00:00:00  1972-01-01 00:00:00  \
# 18         13450.401510         16361.876470         18965.055510
# 14          6631.597314          7655.568963          9530.772896
# 27         20431.092700         22966.144320         27195.113040
# 17         12790.849560         15363.251360         18794.745670
# 13         10350.159060         13319.895680         15798.063620
#
#     1977-01-01 00:00:00  1982-01-01 00:00:00  1987-01-01 00:00:00  \
# 18          23311.34939          26298.63531          31540.97480
# 14          11150.98113          12618.32141          13872.86652
# 27          26982.29052          28397.71512          30281.70459
# 17          21209.05920          21399.46046          23651.32361
# 13          19654.96247          23269.60750          26923.20628
#
#     1992-01-01 00:00:00  1997-01-01 00:00:00  2002-01-01 00:00:00  \
# 18          33965.66115          41283.16433          44683.97525
# 14          17558.81555          24521.94713          34077.04939
# 27          31871.53030          32135.32301          34480.95771
# 17          26790.94961          30246.13063          33724.75778
# 13          25144.39201          28061.09966          31163.20196
#
#     2007-01-01 00:00:00
# 18          49357.19017
# 14          40675.99635
# 27          37506.41907
# 17          36797.93332
# 13          36180.78919

# %% [markdown]
# ### **NaN or Null Cells**

# %%
df_SAFI = df_SAFI[['years_farm',
       'respondent_roof_type', 'respondent_wall_type',
       'respondent_floor_type', 'buildings_in_compound',
       'rooms', 'other_buildings',
        'plots_count', 'note',
        'memb_assoc']]

# %%
df_SAFI.head()
# Out:
#    years_farm respondent_roof_type respondent_wall_type respondent_floor_type  \
# 0          11                grass              muddaub                 earth
# 1           2                grass              muddaub                 earth
# 2          40        mabatisloping          burntbricks                cement
# 3           6        mabatisloping          burntbricks                 earth
# 4          18                grass          burntbricks                 earth
#
#    buildings_in_compound  rooms other_buildings  plots_count  note memb_assoc
# 0                      1      1              no            2   NaN        NaN
# 1                      1      1              no            3   NaN        yes
# 2                      1      1              no            1   NaN        NaN
# 3                      1      1              no            3   NaN        NaN
# 4                      1      1              no            2   NaN        NaN

# %%
df_SAFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   years_farm             131 non-null    int64
#  1   respondent_roof_type   131 non-null    object
#  2   respondent_wall_type   131 non-null    object
#  3   respondent_floor_type  131 non-null    object
#  4   buildings_in_compound  131 non-null    int64
#  5   rooms                  131 non-null    int64
#  6   other_buildings        131 non-null    object
#  7   plots_count            131 non-null    int64
#  8   note                   0 non-null      float64
#  9   memb_assoc             92 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 10.4+ KB

# %%
df_SAFI['memb_assoc']

# %%
#Remove rows with a NaN value in a particular column

df_SAFI = df_SAFI[df_SAFI['memb_assoc'].notna()].reset_index(drop=True)

df_SAFI.info()

# %%
df_SAFI.head()

# %%
#Use dropna() to remove all columns with NaN values

df_SAFI.dropna(inplace=True, axis="columns")
df_SAFI.info()

# %%
# Save cleaned dataframe to a new csv file

df_SAFI.to_csv("/content/drive/MyDrive/python_bootcamp/sample_data/SAFI_cleaned.csv")

# %%
df_SAFI['years_farm'].describe()

# %% [markdown]
# # Exercise!!

# %% [markdown]
# ## Exercise: Cleaning Null Cells
#
#
# 1.   Create a new dataframe called SAFI_subset from the original SAFI.csv that contains the columns respondent_roof_type, respondent_wall_type, respondent_wall_type_other, and respondent_floor_type.
# 2.  Calculate the percentage of cells in the new dataframe that are null. (Hint: Use your mathematical operators!!)

# %%
#Exercise 1:

df_SAFI = pd.read_csv("/content/drive/MyDrive/python_bootcamp/sample_data/SAFI.csv")

df_SAFI_subset = df_SAFI[["respondent_roof_type", "respondent_wall_type",
                          "respondent_wall_type_other", "respondent_floor_type"]]

# %%
# Summing the sums of each column, for a total sum

df_SAFI_subset.isnull().sum().sum()

# %%
col_no = len(df_SAFI_subset.columns)
row_no = len(df_SAFI_subset.index)

total_cells = col_no * row_no

null_cells = df_SAFI_subset.isnull().sum().sum()

percentage_null = ((null_cells/total_cells) * 100)

print(percentage_null)

# %%
df_SAFI.info()
