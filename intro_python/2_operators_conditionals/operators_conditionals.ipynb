# %% [markdown]
# # Demo 2 for Intro Python
#
# ## Introducing:
#
#
#
# *   Operators
# *   Boolean Conditionals

# %% [markdown]
# ## **Part 1: Operators**

# %%
3 + 5
# Out:
# 8

# %%
12 - 10
# Out:
# 2

# %%
2 * 10
# Out:
# 20

# %%
15 / 3
# Out:
# 5.0

# %%
# Modulus (divide by and output the remainder):
15 % 4
# Out:
# 3

# %%
3 ** 2
# Out:
# 9

# %%
# Floor division operator (divides the first operand by the second and returns the largest whole number that is less than or equal to the result.)

15 // 7
# Out:
# 2

# %%
# Order of Precedences (PEMDAS)

3+9*2
# Out:
# 21

# %%
# Math with variables

age = 32

future_age = age + 5

print(future_age)
# Out:
# 37

# %%
# Updating variables with operators

price = 7

price = price + 2

print(price)
# Out:
# 9

# %%
# Using addition operator to combine data

full_name = "James " + "Walsh"

print(full_name)
# Out:
# James Walsh

# %% [markdown]
# ## Exercise: Mathetmatical Operators
#
# Write the code to calculate the net pay of an employee who works:
#
# *   43 hours a week
# *   At $25.50 per hour
#
# If each employee also:
#
# *   Gets a 10% bonus if they work more than 40 hours in a week.
# *   Has 12% tax deducted from their total earnings.

# %%
#Exercise: Mathematical Operators -- Solution

hourly_wage = 25.5
hours_worked = 43

basic_pay = hourly_wage * hours_worked

bonus = basic_pay * 0.10

gross_pay = basic_pay + bonus

net_pay = gross_pay * 0.88

print("$", net_pay)
# Out:
# $ 1061.412

# %% [markdown]
# ## **Part 2: Boolean Statements and Conditionals**

# %%
4 == 4
# Out:
# True

# %%
4 != 4
# Out:
# False

# %%
4 == 3
# Out:
# False

# %%
4 > 3
# Out:
# True

# %%
4 >= 3
# Out:
# True

# %%
"cake" == "cake"
# Out:
# True

# %%
mass = 4

if mass > 3.0:
  print(mass, 'is large')
# Out:
# 4 is large

# %%
m = 5

if m > 3.0:
    print(m, 'is large')
else:
    print(m, 'is small')
# Out:
# 5 is large

# %%
a = 11

if a > 9.0:
    print(a, 'is HUGE')
elif a > 3.0:
    print(a, 'is large')
else:
    print(a, 'is small')
# Out:
# 11 is HUGE

# %%
# Using conditional to update a variable

velocity = 5

if velocity > 20.0:
    print('moving too fast')
else:
    print('adjusting velocity')
    velocity = 50.0
# Out:
# adjusting velocity

# %%
print(velocity)
# Out:
# 50.0

# %%
# What will this print?

pressure = 71.9

if pressure > 50.0:
    pressure = 25.0
elif pressure <= 50.0:
    pressure = 0.0

print(pressure)
# Out:
# 25.0

# %%
## Membership operators

groceries = ["apples", "bread", "cookies"]

if "apples" in groceries:
  print("Apples included!")
# Out:
# Apples included!

# %%
if "milk" not in groceries:
  print("You forgot milk!")
# Out:
# You forgot milk!

# %%
## Logical Operators

if not "milk" in groceries:
  print("You forgot milk!")
# Out:
# You forgot milk!

# %%
if "milk" not in groceries and len(groceries) < 2:
  print("You're list is pretty short!")

# %%
if "milk" not in groceries or len(groceries) < 2:
  print("You're list is pretty short!")
# Out:
# You're list is pretty short!

# %% [markdown]
# ## Exercise: Conditional Statements
#
# Create three lists:
#
# humanities = ["English", "History", "French", "Art History", "Philosophy"]
# sciences = ["Biology", "Chemistry", "Neuroscience", "Physics", "Ecology"]
# social_sciences = ["Political Science", "Sociology", "Anthropology", "Psychology"]
#
# 1.  Using conditionals, write the code that prints “You are a philosopher” if the fifth element of humanities is philosophy (hint: remember indices from Monday!)
# 2.  Now write a program that asks what department you are in, and based on the response, outputs one of the following messages (hint: remember the input() function from Monday!):
#
#
# You are a humanist!
#
# You are a scientist!
#
# You are a social scientist!
#
# You are probably doing something interesting!

# %%
# Exercise: Conditional Statements (Part 1) Solution

if humanities[4] == "Philosophy":
	print("You are a philosopher")

# %%
# Exercise: Conditional Statements (Part 2) Solution

your_department = input("What department do you work in? ")

if your_department in humanities:
	print("You are a humanist")
elif your_department in sciences:
	print("You are a scientist")
elif your_department in social_sciences:
	print("You are a social scientist")
else:
	print("You are probably doing something interesting!")
