# %% [markdown]
# ## **Demo 1 for Intro Python**
# ## Introducing:
#
#
# 1.  Variables
# 2.  Indices/Slices

# %% [markdown]
# ## **Variables**

# %%
print("Hello, World!")

# %%
name = "Claudia"

# %%
age = "32"

# %%
# Python comes with many built-in functions. One of these is 'print' which allows us to print back whatever is passed to the function/

print(name)
# Out:
# Claudia

# %%
# You can print several variables in sequence

print(name, "is", age, "years old")
# Out:
# Claudia is 32 years old

# %%
print(last_name)
# Out:
#   File "<ipython-input-7-04b152c056fa>", line 1
#     print(last name)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# The 'type' function allows us to check what format our data is in.

type(age)
# Out:
# str

# %%
type(name)
# Out:
# str

# %%
new_age = 55

# %%
# We can update variables using the assignment operator (the equals sign!)

age = new_age

# %%
print(age)
# Out:
# 55

# %%
type(age)
# Out:
# int

# %%
name = input("What is your name? ")
print("Hello", name)
# Out:
# What is your name? Claudia
# Hello Claudia

# %%
# We can also converting variable types from one to another

num = "2"
type(num)
# Out:
# str

# %%
# Converting a string to an integer

x = int(num)
type(x)
# Out:
# int

# %%
print(x)
# Out:
# 2

# %%
# Converting an integer to a string

y = str(x)
type(y)
# Out:
# str

# %%
print(y)
# Out:
# 2

# %%
a = 12.0
type(a)
# Out:
# float

# %%
a = "12.0"
type(a)
# Out:
# str

# %%
# Converting a string to a float

a = float("12.0")
type(a)
# Out:
# float

# %%
print(a)
# Out:
# 12.0

# %% [markdown]
# ## Exercise: Variables

# %% [markdown]
# Write the code to ask you how many years you have been at Wash U, and what department you work in. The output should be “Congratulations on working at the X department at Wash U for Y years”.

# %%
years = input("how many years have you worked at WashU? ")

department = input("what department do you work in? ")

print("Congratulations on working at the", department, "department at Wash U for", years, "years")
# Out:
# how many years have you worked at WashU? 2
# what department do you work in? TRIADS
# Congratulations on working at the TRIADS department at Wash U for 2 years

# %% [markdown]
# ## **Part 3: Indices and Slices**

# %%
name = "Claudia"
len(name)
# Out:
# 7

# %%
# Indices

print(name[0])
# Out:
# C

# %%
print(name[-7])
# Out:
# C

# %%
# Slices

print(name[0:3])
# Out:
# Cla

# %%
# Lists

departments = ["music", "philosophy", "chemistry"]

# %%
len(departments)
# Out:
# 3

# %%
print(departments[1])
# Out:
# philosophy

# %%
departments_2 = departments + ["computer science"]

print(departments_2)
# Out:
# ['music', 'philosophy', 'chemistry', 'computer science']

# %% [markdown]
# ## Exercise: Indices and Slices ##
#
# 1.  Create the following list to track your groceries and prices:
#
# groceries = [“apples”, “4”, “milk”, “5.9”, “bread”, “3”, “wine”, “15.5”]
#
# 2.  Use indices to list out only the food items
#
# 3.  Use indices to print out "The cost of apples is $4."

# %%
groceries = ["apples", "4", "milk", "5.9", "bread", "3", "wine", "15.5"]

# %%
print(groceries[0], groceries[2], groceries[4], groceries[6])
# Out:
# apples milk bread wine

# %%
print("The cost of", groceries[0],  "is", "$", groceries[1])
# Out:
# The cost of apples is $ 4
